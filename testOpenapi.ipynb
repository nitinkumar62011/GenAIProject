# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.13.3)
# Collecting openai
#   Downloading openai-1.14.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (2.6.3)
# Requirement already satisfied: sniffio in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.14.1-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/257.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/257.5 kB ? eta -:--:--
#    ---------------------------------- ----- 225.3/257.5 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 257.5/257.5 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.13.3
#     Uninstalling openai-1.13.3:
#       Successfully uninstalled openai-1.13.3
# Successfully installed openai-1.14.1

# %%
from openai import OpenAI

# %%
import openai

# %%
import pandas as pd

# %%
all_model=openai.models.list()

# %%
pd.DataFrame(all_model)
# Out:
#                                     0                      1                2  \
# 0             (id, gpt-3.5-turbo-16k)  (created, 1683758102)  (object, model)
# 1            (id, gpt-3.5-turbo-1106)  (created, 1698959748)  (object, model)
# 2                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 3        (id, gpt-3.5-turbo-16k-0613)  (created, 1685474247)  (object, model)
# 4                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 5        (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 6                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 7                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 8                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 9                 (id, gpt-3.5-turbo)  (created, 1677610602)  (object, model)
# 10           (id, gpt-3.5-turbo-0125)  (created, 1706048358)  (object, model)
# 11           (id, gpt-3.5-turbo-0301)  (created, 1677649963)  (object, model)
# 12           (id, gpt-3.5-turbo-0613)  (created, 1686587434)  (object, model)
# 13  (id, gpt-3.5-turbo-instruct-0914)  (created, 1694122472)  (object, model)
# 14                        (id, tts-1)  (created, 1681940951)  (object, model)
# 15                  (id, davinci-002)  (created, 1692634301)  (object, model)
# 16       (id, gpt-3.5-turbo-instruct)  (created, 1692901427)  (object, model)
# 17                  (id, babbage-002)  (created, 1692634615)  (object, model)
# 18                   (id, tts-1-1106)  (created, 1699053241)  (object, model)
# 19       (id, text-embedding-ada-002)  (created, 1671217299)  (object, model)
# 20       (id, text-embedding-3-small)  (created, 1705948997)  (object, model)
#
#                               3
# 0   (owned_by, openai-internal)
# 1            (owned_by, system)
# 2            (owned_by, system)
# 3            (owned_by, openai)
# 4            (owned_by, system)
# 5            (owned_by, system)
# 6   (owned_by, openai-internal)
# 7            (owned_by, system)
# 8            (owned_by, system)
# 9            (owned_by, openai)
# 10           (owned_by, system)
# 11           (owned_by, openai)
# 12           (owned_by, openai)
# 13           (owned_by, system)
# 14  (owned_by, openai-internal)
# 15           (owned_by, system)
# 16           (owned_by, system)
# 17           (owned_by, system)
# 18           (owned_by, system)
# 19  (owned_by, openai-internal)
# 20           (owned_by, system)

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       4 completion = client.chat.completions.create(
#       5   model="gpt-3.5-turbo",
#       6   messages=[
#    (...)
#       9   ]
#      10 )
#      12 print(completion.choices[0].message)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_client.py:98, in OpenAI.__init__(self, api_key, organization, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      96     api_key = os.environ.get("OPENAI_API_KEY")
#      97 if api_key is None:
# ---> 98     raise OpenAIError(
#      99         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     100     )
#     101 self.api_key = api_key
#     103 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
